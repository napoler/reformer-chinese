# %%
from .generate_test import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-79fd179ea496> in <module>
# ----> 1 from .generate_test import *
#
# ModuleNotFoundError: No module named '__main__.generate_test'; '__main__' is not a package
